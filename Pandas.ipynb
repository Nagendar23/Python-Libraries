# %% [markdown]
# # Pandas
# Pandas is a Python library used for analyzing, cleaning, exploring, and manipulating data.
# Pandas refer to "Python Data Analysis" and was created by Wes McKinney in 2008.
# #### Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# #### What Can Pandas Do?
# Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
# What is average value?
# Max value?
# Min value?
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %% [markdown]
# ### Installation of Pandas
#
# pip install pandas
#
# ### Check version of Pandas
#
# pandas.__version__
#
# ### Import Pandas
#
# import pandas

# %%
import pandas as np

# %%
### Check version of Pandas

print(np.__version__)
# Out:
# 2.3.3

# %%
import pandas as np
dataSet = {
    'cars':['audi','bmw','benz','rr'],
    'noOfUnits':[23,18,19,12]
}
res = np.DataFrame(dataSet)
print(res)
# Out:
#    cars  noOfUnits
# 0  audi         23
# 1   bmw         18
# 2  benz         19
# 3    rr         12

# %% [markdown]
# ### Series
# A Pandas Series is like a column in a table.
#
# It basically prionts the given values with index no.s
#
# It is a one-dimensional array holding data of any type.
#
# use pd.Series(x)

# %%
import pandas as pd
a=[1,3,6]
res=pd.Series(a)
print(res)
# Out:
# 0    1
# 1    3
# 2    6
# dtype: int64

# %% [markdown]
# ### Labels
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
import pandas as pd
a=[1,3,6]
res=pd.Series(a)
#label
print(res[1])
# Out:
# 3

# %% [markdown]
# #### Create Labels
# With the index argument, you can name your own labels.

# %%
import pandas as pd
b=[1,3,6]
res=pd.Series(a,index=['x','y','z'])
print(res)
#we can access using the ddefined index 
print(res['y'])
# Out:
# x    1
# y    3
# z    6
# dtype: int64
# 3

# %%
# Key/Value Objects as Series
# You can also use a key/value object, like a dictionary, when creating a Series.

import pandas as np
screentime={'phone':5, 'laptop':7,'book':1, 'walking':1}
res = pd.Series(screentime)
print(res)
# Out:
# phone      5
# laptop     7
# book       1
# walking    1
# dtype: int64

# %%
# To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.
import pandas as np
screentime={'phone':5, 'laptop':7,'book':1, 'walking':1}
res = pd.Series(screentime,index=['laptop','book'])
print(res)
# Out:
# laptop    7
# book      1
# dtype: int64

# %% [markdown]
# _________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### DataFrames
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# Basically it is used to create table like strcture data
#
# Series is like a column, a DataFrame is the whole table.

# %%
import pandas as pd
data = {
'calories':[420,380,512],
'duration':[50,45,52]
}
res=pd.DataFrame(data)
print(res)
# Out:
#    calories  duration
# 0       420        50
# 1       380        45
# 2       512        52

# %%
# Pandas use the loc attribute to return one or more specified row(s)

print(res.loc[1])   # give all rows of index 1 column
print()
print()
print(res.loc[[0,1]])   # give all rows of index 0,1 column
# Out:
# calories    380
# duration     45
# Name: 1, dtype: int64
#
#
#    calories  duration
# 0       420        50
# 1       380        45

# %%
# Named Indexes
# With the index argument, you can name your own indexes.
import pandas as pd
data = {
'calories':[420,380,512],
'duration':[50,45,52]
}
res=pd.DataFrame(data,index=['day1','day2','day3'])
print(res)
# Out:
#       calories  duration
# day1       420        50
# day2       380        45
# day3       512        52

# %% [markdown]
# #### Load Files Into a DataFrame
# If your data sets are stored in a file, Pandas can load them into a DataFrame.
#
# read_csv('data.csv')

# %%
import pandas as pd
loaded_data = pd.read_csv('pdData.csv')
print(loaded_data)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Read CSV Files
# A simple way to store big data sets is to use CSV files (comma separated files).
#
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

# %%
import pandas as pd
load_data = pd.read_csv('pdData.csv')  #loads the data into that variable 
#if we print direclty will diplay the first and last 5 values , so we use
print(load_data.to_string())        # this displays all the values
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# max_rows
# The number of rows returned is defined in Pandas option settings.
# You can check your system's maximum rows with the pd.options.display.max_rows statement.

import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %%
# import pandas as pd

pd.options.display.max_rows = 9999
df = pd.read_csv('pdData.csv')
print(df) #now it displays all the rows
#generally it displays all but here it is cell issue
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Read JSON
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.
#
# JSON = Python Dictionary
# JSON objects have the same format as Python dictionaries.

# %%
import pandas as pd
json_data = pd.read_json('pdData.json')
print(json_data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}
direct_json=pd.DataFrame(data)
print(direct_json)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ### Analyzing DataFrames
# Viewing the Data
# One of the most used method for getting a quick overview of the DataFrame, is the head() method.
#
# The head() method returns the headers and a specified number of rows, starting from the top.

# %%
import pandas as pd
load_data = pd.read_csv('pdData.csv')
print(load_data.head(10))  #gives first 10 rows
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
#if we don't mention the value in head() , it will print first 5 rows
import pandas as pd
df = pd.read_csv('pdData.csv')
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
# There is also a tail() method for viewing the last rows of the DataFrame.

import pandas as pd
df = pd.read_csv('pdData.csv')
print(df.tail())       # gives last 5 rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# #### Info About the Data
# The DataFrames object has a method called info(), that gives you more information about the data set.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________

# %%
# Overview of Pandas Topics Covered

overview = """
PANDAS LIBRARY OVERVIEW
=======================

1. INTRODUCTION TO PANDAS
    - Python Data Analysis library created by Wes McKinney in 2008
    - Used for analyzing, cleaning, exploring, and manipulating data
    - Answers questions like: correlations, averages, max/min values
    - Cleans messy datasets and handles NULL/empty values

2. SERIES
    - One-dimensional array holding data of any type
    - Created using pd.Series()
    - Has index labels (default: 0, 1, 2, ...)
    - Can have custom labels via index parameter
    - Can be created from lists or dictionaries

3. DATAFRAMES
    - Two-dimensional tabular data structure (rows and columns)
    - Created using pd.DataFrame()
    - Multiple Series combined together
    - Access rows using .loc[] attribute
    - Can have custom index labels

4. LOADING DATA
    - CSV Files: pd.read_csv('filename.csv')
    - JSON Files: pd.read_json('filename.json')
    - Can also load from Python dictionaries directly
    - Display all rows using .to_string()

5. ANALYZING DATA
    - .head(n): Returns first n rows (default 5)
    - .tail(n): Returns last n rows (default 5)
    - .info(): Provides detailed information about the dataset
    - pd.options.display.max_rows: Set maximum rows to display

KEY METHODS SUMMARY:
- pd.Series() - Create a series
- pd.DataFrame() - Create a dataframe
- pd.read_csv() - Read CSV files
- pd.read_json() - Read JSON files
- .loc[] - Access rows by index
- .head() - View first rows
- .tail() - View last rows
- .info() - Get dataset information
- .to_string() - Convert to string format
"""

print(overview)

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Data Cleaning
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# Empty cells
# Data in wrong format
# Wrong data
# Duplicates

# %% [markdown]
# ### Empty Cells
# Empty cells can potentially give you a wrong result when you analyze data.
#
# #### Remove Rows
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.
#
# dropna() method returns a new DataFrame, and will not change the original

# %%
import pandas as pd
loaded_data = pd.read_csv('data1.csv')
new_df = loaded_data.dropna()
print(new_df.to_string()) 
#Notice in the result that some rows have been removed (row 18, 22 and 28).

#These rows had cells with empty values.
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#If you want to change the original DataFrame, use the inplace = True argument:
# the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.
import pandas as pd
df = pd.read_csv('data1.csv')
df.dropna(inplace=True)
print(df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ### Replace Empty Values
# Another way of dealing with empty cells is to insert a new value instead.
#
# This way you do not have to delete entire rows just because of some empty cells.
#
# The fillna() method allows us to replace empty cells with a value:

# %%
import pandas as pd
df=pd.read_csv('data1.csv')
df.fillna(130, inplace=True)          # here it prints 130 in place of empty cells
print(df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ### Replace Only For Specified Columns
#
# To only replace empty values for one column, specify the column name for the DataFrame:

# %%
import pandas as pd
df2=pd.read_csv('data1.csv')
df2.fillna({'Calories':150},inplace=True)         # here for calories column in empty cells replace with 150 
print(df2.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ### Replace Using Mean, Median, or Mode
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:

# %%
# calculate mean

import pandas as pd
df3 = pd.read_csv('data1.csv') # read data
x= df3['Calories'].mean() # define x with  calories coloumn and calc mean of Nan
df3.fillna({"Calories":x}, inplace=True) # replace Nan's with calc mean
print(df3.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
# Replace with MEDIAN (the value in the middle, after you have sorted all values ascending.)

import pandas as pf
df4=pd.read_csv('data1.csv')
y=df4['Calories'].median()
df4.fillna({"Calories":y}, inplace=True)
print(df4.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# Replace with Mode( the value that appears most frequently.)

import pandas as pd 
df5=pd.read_csv('data1.csv')
z=df5['Calories'].mode()[0]     #if we write z=df5['Calories'].mode() => it is no use
df5.fillna({'Calories':z}, inplace=True)
print(df5)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________________

# %% [markdown]
#  ## Cleaning Data of Wrong Format
#
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

# %% [markdown]
# ### Convert Into a Correct Format
# In our Data Frame, we have two cells with the wrong format. Check out row 22 and 26, the 'Date' column should be a string that represents a date:
#
# Pandas has a to_datetime() method for this:

# %%
import pandas as pd
df=pd.read_csv('data2.csv')
df['Date'] = pd.to_datetime(df['Date'], format='mixed')
print(df.to_string())

#he date in row 26 was fixed, but the empty date in row 22 got a NaT (Not a Time) value,
# # in other words an empty value. One way to deal with empty values is simply removing the entire row.
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
# # Removing Rows
# The result from the converting in the example above gave us a NaT value, which can be handled as a NULL value, 
# and we can remove the row by using the dropna() method.
df.dropna(subset=['Date'], inplace=True)
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Fixing Wrong Data
#
# "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someone registered "199" instead of "1.99".
# Sometimes you can spot wrong data by looking at the data set, because you have an expectation of what it should be.

# %% [markdown]
# ### Replacing Values
# One way to fix wrong values is to replace them with something else.
#
# In our example, it is most likely a typo, and the value should be "45" instead of "450", and we could just insert "45" in row 7
#
# To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries.

# %%
# Set "Duration" = 45 in row 7:
df.loc[7, 'Duration'] = 45
print(df.to_string())  #450 in row 7 changes to 45
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
for x in df.index:
    if df.loc[x, 'Duration'] > 120:       # for Duration values which has greater than 120 is changed to 120
        df.loc[x,'Duration'] = 120
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# #### Removing Rows
# Another way of handling wrong data is to remove the rows that contains wrong data.
#
# This way you do not have to find out what to replace them with, and there is a good chance you do not need them to do your analyses.

# %%
for x in df.index:
    if df.loc[x,"Duration"] >120:
        df.drop(x, inplace=True)   # remvoe the data that has wrong data

# %% [markdown]
# ### Removing Duplicates
# Discovering Duplicates
# Duplicate rows are rows that have been registered more than one time.
#
# To discover duplicates, we can use the duplicated() method.
#
# The duplicated() method returns a Boolean values for each row:

# %%
import pandas as pd
df=pd.read_csv('data2.csv')
print(df.duplicated())   # gives whether duplicate or not in boolean value
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# #### Removing Duplicates
# To remove duplicates, use the drop_duplicates() method.

# %%
import pandas as pd
df=pd.read_csv('data2.csv')
df.drop_duplicates(inplace=True)
print(df.to_string())      # here all the duplicated values are deleted which is row 12
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Data Correlations
# ### Finding Relationships
# A great aspect of the Pandas module is the corr() method.
#
# The corr() method calculates the relationship between each column in your data set.
#
# The corr() method ignores "not numeric" columns.

# %%
import pandas as pd
df = pd.read_csv('data3.csv')
print(df.corr())
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
#
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# #### Good correlation:
#   safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.
#
# #### Perfect Correlation:
# We can see that "Duration" and "Duration" got the number 1.000000, which makes sense, each column always has a perfect relationship with itself.
#
# #### Good Correlation:
# "Duration" and "Calories" got a 0.922721 correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out.
#
# #### Bad Correlation:
# "Duration" and "Maxpulse" got a 0.009403 correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa.

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Plotting
# Pandas uses the plot() method to create diagrams.
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('data3.csv')
df.plot()
df.show()

#not compulsory but, 
# these two lines helps compiler to draw
plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15712\3255355258.py in ?()
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 df=pd.read_csv('data3.csv')
#       5 df.plot()
# ----> 6 df.show()
#       7
#       8 # these two lines helps compiler to draw
#       9 plt.savefig(sys.stdout.buffer)
#
# c:\Users\varka\Desktop\Pandas\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %% [markdown]
# ### Scatter Plot
# Specify that you want a scatter plot with the kind argument:
#
# kind = 'scatter'
#
# A scatter plot needs an x- and a y-axis.
#
# x = 'Duration', y = 'Calories'

# %%
import pandas as pd
df=pd.read_csv('data3.csv')
df.plot(kind='scatter', x='Duration', y='Calories')
df.show()        # higer the duration higher the calories lost
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15712\715201157.py in ?()
#       1 import pandas as pd
#       2 df=pd.read_csv('data3.csv')
#       3 df.plot(kind='scatter', x='Duration', y='Calories')
# ----> 4 df.show()
#
# c:\Users\varka\Desktop\Pandas\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %% [markdown]
# ### Histogram
# Use the kind argument to specify that you want a histogram:
#
# kind = 'hist'
#
# A histogram needs only one column.
#
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?

# %%
#Three lines to make our compiler able to draw:
import sys
import matplotlib
matplotlib.use('Agg')
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data.csv')
df["Duration"].plot(kind = 'hist')
plt.show()
#Two  lines to make our compiler able to draw:
plt.savefig(sys.stdout.buffer)
sys.stdout.flush()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data3.csv')
df['Duration'].hist()
plt.show()

# %% [markdown]
# __________________________________________________________________

# %% [markdown]
# ## uncovered topics

# %%
import pandas as pd
df = pd.read_csv('data3.csv')
print(df.loc[1:5,['Duration','Calories']])
# Out:
#    Duration  Calories
# 1        60     479.0
# 2        60     340.0
# 3        45     282.4
# 4        45     406.0
# 5        60     300.0

# %%
df["Duration"].unique()
# Out:
# array([ 60,  45,  30,  80,  20, 210, 160, 180, 150, 300,  90, 120, 270,
#         15,  25,  75])

# %%
df['Duration'].value_counts()
# Out:
# Duration
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 75      2
# 160     2
# 210     2
# 15      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: count, dtype: int64

# %%
# creating new column called O2 which is 25 less to pulse
df['O2'] = df['Pulse']-25

# %%
df['O2']
# Out:
# 0       85
# 1       92
# 2       78
# 3       84
# 4       92
#       ...
# 164     80
# 165     85
# 166     90
# 167     95
# 168    100
# Name: O2, Length: 169, dtype: int64

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# O2          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool
